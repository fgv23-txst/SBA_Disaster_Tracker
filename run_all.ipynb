# %%
# %run clean_sba_data.py
# Out:
# Rows: 7044
# Columns: 16
#   disaster_number state        disaster_description incident_start_date  \
# 0        PA-20040    PA  Severe Storms and Flooding          2026-07-28
# 1        PA-20040    PA  Severe Storms and Flooding          2026-07-28
# 2        PA-20040    PA  Severe Storms and Flooding          2026-07-28
# 3        PA-20040    PA  Severe Storms and Flooding          2026-07-28
# 4        PA-20040    PA  Severe Storms and Flooding          2026-07-28
#
#   incident_end_date declaration_date          declaration_type  \
# 0        2026-07-28       2026-08-19  SBA Declaration (Agency)
# 1        2026-07-28       2026-08-19  SBA Declaration (Agency)
# 2        2026-07-28       2026-08-19  SBA Declaration (Agency)
# 3        2026-07-28       2026-08-19  SBA Declaration (Agency)
# 4        2026-07-28       2026-08-19  SBA Declaration (Agency)
#
#               status physical_deadline_date eidl_deadline_date  fema_number  \
# ...

# %%
# %run create_json.py
# Out:
# SBA_disaster_Final.json created successfully.
# Total records: 7044

# %%
# %run update_sba_data.py
# Out:
# SBA API status: 200
# Total disasters: 362
# Processing 25 of 362
# Processing 50 of 362
# Processing 75 of 362
# Processing 100 of 362
# Processing 125 of 362
# Processing 150 of 362
# Processing 175 of 362
# Processing 200 of 362
# Processing 225 of 362
# Processing 250 of 362
# Processing 275 of 362
# Processing 300 of 362
# Processing 325 of 362
# Processing 350 of 362
# Loop time: 0.004015922546386719 seconds
#
# Disasters with no county rows:
# {'ZZ-00021'}
# CSV file 'Data/sba_disaster_data.csv' has been created.
# Total rows written: 7222

# %%
# %run clean_sba_data.py
# Out:
# Rows: 7044
# Columns: 16
#   disaster_number state        disaster_description incident_start_date  \
# 0        PA-20040    PA  Severe Storms and Flooding          2026-07-28
# 1        PA-20040    PA  Severe Storms and Flooding          2026-07-28
# 2        PA-20040    PA  Severe Storms and Flooding          2026-07-28
# 3        PA-20040    PA  Severe Storms and Flooding          2026-07-28
# 4        PA-20040    PA  Severe Storms and Flooding          2026-07-28
#
#   incident_end_date declaration_date          declaration_type  \
# 0        2026-07-28       2026-08-19  SBA Declaration (Agency)
# 1        2026-07-28       2026-08-19  SBA Declaration (Agency)
# 2        2026-07-28       2026-08-19  SBA Declaration (Agency)
# 3        2026-07-28       2026-08-19  SBA Declaration (Agency)
# 4        2026-07-28       2026-08-19  SBA Declaration (Agency)
#
#               status physical_deadline_date eidl_deadline_date  fema_number  \
# ...

# %%
# %run run_update.py
# Out:
# STEP 1: Updating SBA data
#
# STEP 2: Cleaning SBA data
#
# STEP 3: Creating JSON
#
# All SBA updates completed successfully!
